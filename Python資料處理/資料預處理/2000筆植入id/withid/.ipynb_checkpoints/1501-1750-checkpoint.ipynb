# %%
import pandas as pd 
import numpy as np

# %%
table1=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆活動資料植入ID工作/原始csv檔區/1501-1750(補齊).csv')
table1
# Out:
#          id zh_name     年級 en_name  gender    birthday  age  \
# 0     733.0     黃郁婷    NaN     NaN     0.0  1987/11/30  NaN
# 1    2053.0     吳怡萱    NaN     NaN     NaN         NaN  NaN
# 2    2391.0     王澤民  106.0     NaN     NaN         NaN  NaN
# 3    2451.0     葉衛廷    NaN     NaN     NaN  1986/11/14  NaN
# 4    2735.0     詹無愁    NaN     NaN     NaN         NaN  NaN
# ..      ...     ...    ...     ...     ...         ...  ...
# 129     NaN     劉宇真    NaN     NaN     NaN         NaN  NaN
# 130     NaN     劉惠美    NaN     NaN     0.0    1959/8/4  NaN
# 131     NaN     鄭景徽    NaN     NaN     1.0    1982/4/6  NaN
# 132     NaN     駱昱菘    NaN     NaN     NaN  1992/10/22  NaN
# 133     NaN     羅仕宇    NaN     NaN     NaN   1992/5/29  NaN
#
#                         email  zip_code region county district  \
# 0           1412388@gmail.com       NaN    NaN    NaN      NaN
# 1         wuyisuan@scu.edu.tw       NaN    NaN    NaN      NaN
# ...

# %%
tableid=table1.dropna(subset=['id'])
tableid
# Out:
#            id zh_name     年級 en_name  gender    birthday  age  \
# 0       733.0     黃郁婷    NaN     NaN     0.0  1987/11/30  NaN
# 1      2053.0     吳怡萱    NaN     NaN     NaN         NaN  NaN
# 2      2391.0     王澤民  106.0     NaN     NaN         NaN  NaN
# 3      2451.0     葉衛廷    NaN     NaN     NaN  1986/11/14  NaN
# 4      2735.0     詹無愁    NaN     NaN     NaN         NaN  NaN
# ..        ...     ...    ...     ...     ...         ...  ...
# 104  101950.0     張湘茹    NaN     NaN     0.0   1993/6/12  NaN
# 105  110321.0     王怡韻    NaN     NaN     0.0   1963/8/11  NaN
# 106  110330.0     林旻憶    NaN     NaN     NaN         NaN  NaN
# 107  110335.0     楊秉鈞    NaN     NaN     NaN         NaN  NaN
# 108  113700.0     廖淑英    NaN     NaN     NaN  1986/10/18  NaN
#
#                          email  zip_code region county district  \
# 0            1412388@gmail.com       NaN    NaN    NaN      NaN
# 1          wuyisuan@scu.edu.tw       NaN    NaN    NaN      NaN
# ...

# %%
table_original=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆活動資料植入ID工作/原始csv檔區/1501-1750(原始).csv')
table_original_select=table_original.loc[:,['id','zh_name','畢業學系','年級','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num']]
table_original_select
# Out:
#           id zh_name 畢業學系    年級 en_name  gender    birthday  age  \
# 0    10425.0     何基丞  歷史系  69.0     NaN     NaN         NaN  NaN
# 1    14054.0     杜碧芳  歷史系  74.0     NaN     0.0  1962/10/16  NaN
# 2    16802.0     盧瑞卿  歷史系  77.0     NaN     NaN         NaN  NaN
# 3        NaN     吳志偉  歷史系  85.0     NaN     NaN         NaN  NaN
# 4        NaN     蔡豐任  歷史系  94.0     NaN     NaN   1988/7/19  NaN
# ..       ...     ...  ...   ...     ...     ...         ...  ...
# 994      NaN     NaN  NaN   NaN     NaN     NaN         NaN  NaN
# 995      NaN     NaN  NaN   NaN     NaN     NaN         NaN  NaN
# 996      NaN     NaN  NaN   NaN     NaN     NaN         NaN  NaN
# 997      NaN     NaN  NaN   NaN     NaN     NaN         NaN  NaN
# 998      NaN     NaN  NaN   NaN     NaN     NaN         NaN  NaN
#
#                         email  zip_code region county district  \
# 0      jim.ho@coremaxcorp.com       NaN     TW    新竹縣      湖口鄉
# ...

# %%
concat=pd.concat([tableid,table_original])
concat
# Out:
#          id zh_name     年級 en_name  gender    birthday  age  \
# 0     733.0     黃郁婷    NaN     NaN     0.0  1987/11/30  NaN
# 1    2053.0     吳怡萱    NaN     NaN     NaN         NaN  NaN
# 2    2391.0     王澤民  106.0     NaN     NaN         NaN  NaN
# 3    2451.0     葉衛廷    NaN     NaN     NaN  1986/11/14  NaN
# 4    2735.0     詹無愁    NaN     NaN     NaN         NaN  NaN
# ..      ...     ...    ...     ...     ...         ...  ...
# 994     NaN     NaN    NaN     NaN     NaN         NaN  NaN
# 995     NaN     NaN    NaN     NaN     NaN         NaN  NaN
# 996     NaN     NaN    NaN     NaN     NaN         NaN  NaN
# 997     NaN     NaN    NaN     NaN     NaN         NaN  NaN
# 998     NaN     NaN    NaN     NaN     NaN         NaN  NaN
#
#                         email  zip_code region  ... tele      id_num  \
# 0           1412388@gmail.com       NaN    NaN  ...  NaN  A227724495
# 1         wuyisuan@scu.edu.tw       NaN    NaN  ...  NaN         NaN
# ...

# %%
concat_select=concat.loc[:,['id','zh_name','畢業學系','年級','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num','note']]
concat_select
# Out:
#          id zh_name 畢業學系     年級 en_name  gender    birthday  age  \
# 0     733.0     黃郁婷  NaN    NaN     NaN     0.0  1987/11/30  NaN
# 1    2053.0     吳怡萱  NaN    NaN     NaN     NaN         NaN  NaN
# 2    2391.0     王澤民  NaN  106.0     NaN     NaN         NaN  NaN
# 3    2451.0     葉衛廷  NaN    NaN     NaN     NaN  1986/11/14  NaN
# 4    2735.0     詹無愁  NaN    NaN     NaN     NaN         NaN  NaN
# ..      ...     ...  ...    ...     ...     ...         ...  ...
# 994     NaN     NaN  NaN    NaN     NaN     NaN         NaN  NaN
# 995     NaN     NaN  NaN    NaN     NaN     NaN         NaN  NaN
# 996     NaN     NaN  NaN    NaN     NaN     NaN         NaN  NaN
# 997     NaN     NaN  NaN    NaN     NaN     NaN         NaN  NaN
# 998     NaN     NaN  NaN    NaN     NaN     NaN         NaN  NaN
#
#                         email  zip_code region county district address  \
# 0           1412388@gmail.com       NaN    NaN    NaN      NaN     NaN
# ...

# %%
concatdrop_zh_name=concat_select.dropna(subset=['zh_name'])
concatdrop_zh_name
# Out:
#          id zh_name 畢業學系     年級 en_name  gender    birthday  age  \
# 0     733.0     黃郁婷  NaN    NaN     NaN     0.0  1987/11/30  NaN
# 1    2053.0     吳怡萱  NaN    NaN     NaN     NaN         NaN  NaN
# 2    2391.0     王澤民  NaN  106.0     NaN     NaN         NaN  NaN
# 3    2451.0     葉衛廷  NaN    NaN     NaN     NaN  1986/11/14  NaN
# 4    2735.0     詹無愁  NaN    NaN     NaN     NaN         NaN  NaN
# ..      ...     ...  ...    ...     ...     ...         ...  ...
# 245     NaN     盧令北  NaN    NaN     NaN     NaN         NaN  NaN
# 246     NaN     盧俊賢  NaN    NaN     NaN     NaN         NaN  NaN
# 247     NaN     羅進誠  NaN    NaN     NaN     NaN         NaN  NaN
# 248     NaN     羅美理  NaN    NaN     NaN     NaN         NaN  NaN
# 249     NaN     莊媖琁  NaN    NaN     NaN     NaN         NaN  NaN
#
#                         email  zip_code region county district address  \
# 0           1412388@gmail.com       NaN    NaN    NaN      NaN     NaN
# ...

# %%
concatdropduplicate=concatdrop_zh_name.drop_duplicates(subset=['zh_name'],keep=False)
concatdropduplicate
# Out:
#      id zh_name 畢業學系     年級 en_name  gender    birthday  age  \
# 8   NaN     吳明娟  歷史系  108.0     NaN     NaN   1997/3/21  NaN
# 9   NaN      羅傑  歷史系  109.0     NaN     1.0    1998/3/1  NaN
# 10  NaN     鍾翠雲  歷史系   80.0     NaN     NaN         NaN  NaN
# 11  NaN     黃峯彬  歷史系   81.0     NaN     1.0  1973/10/21  NaN
# 12  NaN     郭乃溱  歷史系  105.0     NaN     NaN         NaN  NaN
# ..   ..     ...  ...    ...     ...     ...         ...  ...
# 245 NaN     盧令北  NaN    NaN     NaN     NaN         NaN  NaN
# 246 NaN     盧俊賢  NaN    NaN     NaN     NaN         NaN  NaN
# 247 NaN     羅進誠  NaN    NaN     NaN     NaN         NaN  NaN
# 248 NaN     羅美理  NaN    NaN     NaN     NaN         NaN  NaN
# 249 NaN     莊媖琁  NaN    NaN     NaN     NaN         NaN  NaN
#
#                           email  zip_code region county district  \
# 8           e22583@yahoo.com.tw       NaN     TW    高雄市      前金區
# 9       roger87030122@gmail.com       NaN    NaN    NaN      NaN
# ...

# %%
concatdropduplicate.to_csv('ellen_modify-class.csv',encoding='utf-8-sig')
