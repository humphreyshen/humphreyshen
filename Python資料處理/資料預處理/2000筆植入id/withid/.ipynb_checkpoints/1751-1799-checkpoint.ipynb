# %%
import pandas as pd 
import numpy as np

# %%
table1=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆活動資料植入ID工作/原始csv檔區/1751-1799.csv')
table1
# Out:
#     作業編號        id zh_name        en_name  gender    birthday  age  \
# 0   1751       NaN     葉俐妤            NaN     NaN         NaN  NaN
# 1   1752       NaN     葉麗晴            NaN     NaN         NaN  NaN
# 2   1753       NaN     葛煥昭            NaN     NaN         NaN  NaN
# 3   1754       NaN     董嘉青            NaN     NaN         NaN  NaN
# 4   1755       NaN     蔡宗榮            NaN     NaN         NaN  NaN
# 5   1756  113687.0     蔡惠惠            NaN     NaN         NaN  NaN
# 6   1757       NaN     蔡柱國            NaN     1.0         NaN  NaN
# 7   1758       NaN     蔣宜卿            NaN     NaN         NaN  NaN
# 8   1759       NaN     蕭義明            NaN     1.0  1953/10/10  NaN
# 9   1760  102510.0      薛琪            NaN     NaN         NaN  NaN
# 10  1761       NaN     蘇娟玉            NaN     NaN  1959/12/29  NaN
# 11  1762       NaN     蘇雄義            NaN     NaN         NaN  NaN
# 12  1763       NaN     許振聲            NaN     NaN         NaN  NaN
# ...

# %%
table1_select=table1.loc[:,['id','zh_name','年級','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num','last_edit','bye']]
table1_select
# Out:
#           id zh_name    年級        en_name  gender    birthday  age  \
# 0        NaN     葉俐妤   NaN            NaN     NaN         NaN  NaN
# 1        NaN     葉麗晴   NaN            NaN     NaN         NaN  NaN
# 2        NaN     葛煥昭   NaN            NaN     NaN         NaN  NaN
# 3        NaN     董嘉青   NaN            NaN     NaN         NaN  NaN
# 4        NaN     蔡宗榮   NaN            NaN     NaN         NaN  NaN
# 5   113687.0     蔡惠惠   NaN            NaN     NaN         NaN  NaN
# 6        NaN     蔡柱國  49.0            NaN     1.0         NaN  NaN
# 7        NaN     蔣宜卿   NaN            NaN     NaN         NaN  NaN
# 8        NaN     蕭義明   NaN            NaN     1.0  1953/10/10  NaN
# 9   102510.0      薛琪   NaN            NaN     NaN         NaN  NaN
# 10       NaN     蘇娟玉   NaN            NaN     NaN  1959/12/29  NaN
# 11       NaN     蘇雄義   NaN            NaN     NaN         NaN  NaN
# 12       NaN     許振聲   NaN            NaN     NaN         NaN  NaN
# ...

# %%
table1id=table1_select.dropna(subset=['id'])
table1id
# Out:
#           id zh_name  年級 en_name  gender birthday  age                  email  \
# 5   113687.0     蔡惠惠 NaN     NaN     NaN      NaN  NaN  joanna12099@gmail.com
# 9   102510.0      薛琪 NaN     NaN     NaN      NaN  NaN    z54782003@gmail.com
# 13  116419.0     許昱智 NaN     NaN     NaN      NaN  NaN                    NaN
# 17  117006.0     賴欣宜 NaN     NaN     NaN      NaN  NaN   hie123t@yahoo.com.tw
# 19  103536.0     郭冠頡 NaN     NaN     NaN      NaN  NaN                    NaN
# 21  110351.0     郭家馨 NaN     NaN     NaN      NaN  NaN    c60123@yahoo.com.tw
# 44  116978.0     黃思堯 NaN     NaN     NaN      NaN  NaN      siyao39@gmail.com
# 45  110336.0     黃正文 NaN     NaN     NaN      NaN  NaN    egg80729@gmail.com
#
#     zip_code region county district address        cell tele      id_num
# 5        NaN    NaN    NaN      NaN     NaN   916408773  NaN         NaN
# 9        NaN    NaN    NaN      NaN     NaN  0912064648  NaN  F228335291
# ...

# %%
table1id.to_csv('1751-1799_withid.csv',encoding='utf-8-sig')

# %%
noidmask=table1_select['id'].isnull()
table1noid=table1_select[noidmask]
table1noid
# Out:
#     id zh_name    年級        en_name  gender    birthday  age  \
# 0  NaN     葉俐妤   NaN            NaN     NaN         NaN  NaN
# 1  NaN     葉麗晴   NaN            NaN     NaN         NaN  NaN
# 2  NaN     葛煥昭   NaN            NaN     NaN         NaN  NaN
# 3  NaN     董嘉青   NaN            NaN     NaN         NaN  NaN
# 4  NaN     蔡宗榮   NaN            NaN     NaN         NaN  NaN
# 6  NaN     蔡柱國  49.0            NaN     1.0         NaN  NaN
# 7  NaN     蔣宜卿   NaN            NaN     NaN         NaN  NaN
# 8  NaN     蕭義明   NaN            NaN     1.0  1953/10/10  NaN
# 10 NaN     蘇娟玉   NaN            NaN     NaN  1959/12/29  NaN
# 11 NaN     蘇雄義   NaN            NaN     NaN         NaN  NaN
# 12 NaN     許振聲   NaN            NaN     NaN         NaN  NaN
# 14 NaN     許育仁   NaN            NaN     NaN         NaN  NaN
# 15 NaN     詹乾隆   NaN            NaN     NaN         NaN  NaN
# 16 NaN     賴才琪   NaN            NaN     NaN         NaN  NaN
# ...

# %%
table1noid.to_csv('1751-1799_idisnull.csv',encoding='utf-8-sig')
