# %%
import pandas as pd
import numpy as np

table501_750=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆植入ID/原始csv檔區/501-750.csv')
table501_750_select=table501_750.loc[:,['id','zh_name','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num']]
table501_750_select
# Out:
#            id zh_name        en_name  gender    birthday  age  \
# 0         NaN     李昶弘            NaN     1.0   1962/6/23  NaN
# 1         NaN     苗培榮            NaN     0.0   1965/11/9  NaN
# 2         NaN     陳學翰            NaN     1.0  2002/10/22  NaN
# 3      9930.0     賴錦雀            NaN     0.0         NaN  NaN
# 4     70060.0     張晉銓            NaN     1.0         NaN  NaN
# ..        ...     ...            ...     ...         ...  ...
# 243  111285.0     陳俞璇            NaN     0.0   1997/4/26  NaN
# 244  111290.0     張祐瑋            NaN     NaN         NaN  NaN
# 245  111273.0     沈佳妍            NaN     0.0  1996/12/19  NaN
# 246  104484.0     王儀瑄            NaN     NaN    1995/5/4  NaN
# 247   13343.0     鄒淑英  Su-Ying, Tsou     0.0    1961/1/5  NaN
#
#                            email  zip_code region county district  \
# 0            K7654321@scu.edu.tw       NaN    NaN    NaN      NaN
# 1                miao@scu.edu.tw       NaN    NaN    NaN      NaN
# ...

# %%
table251_500=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆植入ID/personal正式上傳/251-500_clean.csv')
table251_500_select=table251_500.loc[:,['id','zh_name','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num']]
table251_500_select
# Out:
#            id zh_name         en_name  gender    birthday  age  \
# 0     73628.0     李淑芳             NaN     0.0         NaN  NaN
# 1     17024.0     王孟鈺             NaN     NaN    1966/5/1  NaN
# 2     96605.0     陳沛玲             NaN     0.0   1971/8/21  NaN
# 3     28827.0     陳琬菁             NaN     0.0  1974/10/28  NaN
# 4     47497.0     李筱筠             NaN     NaN         NaN  NaN
# ..        ...     ...             ...     ...         ...  ...
# 184  103679.0     徐先駒             NaN     NaN         NaN  NaN
# 185  113872.0     蔡郁銘             NaN     1.0  1993/12/23  NaN
# 186   93449.0     簡嘉進             NaN     1.0  1976/12/26  NaN
# 187  110682.0     許志能  HSU, CHIH-NENG     1.0   1970/7/31  NaN
# 188   80962.0     張鑑鵬             NaN     1.0  1972/12/30  NaN
#
#                           email  zip_code region county district  \
# 0             ceo0520@gmail.com       NaN    NaN    NaN      NaN
# 1          monmom0501@gmail.com       NaN    NaN    NaN      NaN
# ...

# %%
table751_1000=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆植入ID/原始csv檔區/751-1000.csv')
table751_1000_select=table751_1000.loc[:,['id','zh_name','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num']]
table751_1000_select
# Out:
#            id zh_name         en_name  gender    birthday  age  \
# 0     67193.0     楊雅鈞             NaN     NaN  1990/11/07  NaN
# 1     97923.0     吳雅集             NaN     0.0  1991/03/10  NaN
# 2    101171.0     劉曜齊  LIOU, YAW-CHYI     NaN  1994/02/21  NaN
# 3    101248.0     黃廷宇  HUANG, TING-YU     1.0  1994/04/02  NaN
# 4    111174.0     邱鈺婷    QIU, YU-TING     0.0  1996/12/04  NaN
# ..        ...     ...             ...     ...         ...  ...
# 245   33319.0     楊斌義             NaN     NaN  1976/07/17  NaN
# 246   91396.0     李承宗             NaN     1.0  1981/07/17  NaN
# 247   91018.0     周彥廷             NaN     1.0  1982/11/09  NaN
# 248   91021.0     陳岳駒             NaN     NaN  1983/01/07  NaN
# 249   91020.0     鄭弘偉             NaN     1.0  1983/07/20  NaN
#
#                           email  zip_code region county district  \
# 0         z0751983162@gmail.com     261.0     TW    宜蘭縣      頭城鎮
# 1      kikilove0310@hotmail.com     112.0     TW    台北市      北投區
# ...

# %%
table1001_1250=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆植入ID/原始csv檔區/1001-1250.csv')
table1001_1250_select=table1001_1250.loc[:,['id','zh_name','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num']]
table1001_1250_select
# Out:
#         id zh_name en_name  gender    birthday  age  \
# 0      NaN     趙詩華     NaN     1.0  1986/05/16  NaN
# 1      NaN     沈柏楷     NaN     1.0  1986/06/02  NaN
# 2      NaN     洪欣如     NaN     NaN  1986/08/13  NaN
# 3      NaN     陳哲寬     NaN     NaN  1987/09/07  NaN
# 4      NaN     李珮慈     NaN     0.0  1988/02/12  NaN
# ..     ...     ...     ...     ...         ...  ...
# 238   9518     蔡鴻賢     NaN     1.0  1955/07/05  NaN
# 239    NaN      陳惠     NaN     NaN         NaN  NaN
# 240  73694     高妙玲     NaN     NaN         NaN  NaN
# 241  14490     章本斐     NaN     0.0         NaN  NaN
# 242  21380     陳澤輝     NaN     1.0  1968/11/29  NaN
#
#                            email  zip_code region county district  \
# 0         dourbest0516@gmail.com       NaN     TW    台北市      松山區
# 1    Tony-PK.Shen@NANSHAN.com.tw       NaN     TW    台北市      信義區
# 2              togoily@gmail.com       NaN     TW    新北市      汐止區
# 3              jhekuan@gmail.com       NaN     TW    台北市      松山區
# ...

# %%
concating_251_1250=pd.concat([table251_500_select,table501_750_select,table751_1000_select,table1001_1250_select])
concating_251_1250
# Out:
#           id zh_name en_name  gender    birthday  age  \
# 0    73628.0     李淑芳     NaN     0.0         NaN  NaN
# 1    17024.0     王孟鈺     NaN     NaN    1966/5/1  NaN
# 2    96605.0     陳沛玲     NaN     0.0   1971/8/21  NaN
# 3    28827.0     陳琬菁     NaN     0.0  1974/10/28  NaN
# 4    47497.0     李筱筠     NaN     NaN         NaN  NaN
# ..       ...     ...     ...     ...         ...  ...
# 238     9518     蔡鴻賢     NaN     1.0  1955/07/05  NaN
# 239      NaN      陳惠     NaN     NaN         NaN  NaN
# 240    73694     高妙玲     NaN     NaN         NaN  NaN
# 241    14490     章本斐     NaN     0.0         NaN  NaN
# 242    21380     陳澤輝     NaN     1.0  1968/11/29  NaN
#
#                         email  zip_code region county district  \
# 0           ceo0520@gmail.com       NaN    NaN    NaN      NaN
# 1        monmom0501@gmail.com       NaN    NaN    NaN      NaN
# 2        Steffi1545@gmail.com       NaN    NaN    NaN      NaN
# ...

# %%
final_id_251_1250=concating_251_1250.dropna(subset=['id'])
final_id_251_1250
# Out:
#           id zh_name en_name  gender    birthday  age  \
# 0    73628.0     李淑芳     NaN     0.0         NaN  NaN
# 1    17024.0     王孟鈺     NaN     NaN    1966/5/1  NaN
# 2    96605.0     陳沛玲     NaN     0.0   1971/8/21  NaN
# 3    28827.0     陳琬菁     NaN     0.0  1974/10/28  NaN
# 4    47497.0     李筱筠     NaN     NaN         NaN  NaN
# ..       ...     ...     ...     ...         ...  ...
# 237        5     陸大文     NaN     1.0  1954/05/26  NaN
# 238     9518     蔡鴻賢     NaN     1.0  1955/07/05  NaN
# 240    73694     高妙玲     NaN     NaN         NaN  NaN
# 241    14490     章本斐     NaN     0.0         NaN  NaN
# 242    21380     陳澤輝     NaN     1.0  1968/11/29  NaN
#
#                         email  zip_code region county district  \
# 0           ceo0520@gmail.com       NaN    NaN    NaN      NaN
# 1        monmom0501@gmail.com       NaN    NaN    NaN      NaN
# 2        Steffi1545@gmail.com       NaN    NaN    NaN      NaN
# ...

# %%
final_id_251_1250.to_csv('251-1250_clean.csv',encoding='utf-8-sig')

# %%
concating_251_1250_id_null_mask=concating_251_1250['id'].isnull()
concating_251_1250_idisnull=concating_251_1250[concating_251_1250_id_null_mask]
concating_251_1250_idisnull
# Out:
#       id zh_name en_name  gender    birthday  age  \
# 0    NaN     李昶弘     NaN     1.0   1962/6/23  NaN
# 1    NaN     苗培榮     NaN     0.0   1965/11/9  NaN
# 2    NaN     陳學翰     NaN     1.0  2002/10/22  NaN
# 7    NaN     寧瑞祥     NaN     1.0    1962/7/6  NaN
# 8    NaN     李鳳梧     NaN     NaN         NaN  NaN
# ..   ...     ...     ...     ...         ...  ...
# 208  NaN     林秀聰     NaN     0.0  1959/06/16  NaN
# 215  NaN     張培誠     NaN     NaN         NaN  NaN
# 219  NaN     林怡君     NaN     NaN         NaN  NaN
# 234  NaN     陳碧華     NaN     NaN         NaN  NaN
# 239  NaN      陳惠     NaN     NaN         NaN  NaN
#
#                             email  zip_code region county district  \
# 0             K7654321@scu.edu.tw       NaN    NaN    NaN      NaN
# 1                 miao@scu.edu.tw       NaN    NaN    NaN      NaN
# 2             zchen2775@gmail.com     333.0     TW    桃園市      龜山區
# 7             ningroger@gmail.com       NaN    NaN    NaN      NaN
# ...

# %%
concating_251_1250_idisnull.to_csv('251-1250_idnull.csv',encoding='utf-8-sig')
