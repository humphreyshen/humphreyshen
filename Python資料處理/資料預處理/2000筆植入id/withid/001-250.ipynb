# %%
# import numpy as np
import pandas as pd

table1=pd.read_csv("/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆活動資料植入ID工作/原始csv檔區/001-250.csv")
table1.head()
# Out:
#    作業編號        ID                    畢業學系   年級 zh_name           en_name  \
# 0     1  113435.0                  資訊管理學系  108     巫沚臻     WU, CHIH-CHEN
# 1     2  107203.0                    法律學系  106     蕭君鈴  HSIAO, CHUN-LING
# 2     3  105797.0            經濟學系、108級企研所  106     黃奕豪               NaN
# 3     4   25768.0        85級經濟系研究所、83級經濟系   83     鄭淑穎               NaN
# 4     5   85662.0  96級英文系 /98級EMBA/06級經濟系   96     魯亮君               NaN
#
#    gender    birthday  age                  email  ...  district  \
# 0     NaN  1997/03/03  NaN  joanwu11226@gmail.com  ...       板橋區
# 1     NaN  1984/03/31  NaN  courage0331@gmail.com  ...       萬華區
# 2     NaN  1994/10/08  NaN  derek831008@gmail.com  ...       NaN
# 3     NaN         NaN  NaN  sweetjeng@itri.org.tw  ...       東區光
# 4     1.0  1976/04/02  NaN  ryan.lu@moserbaer.net  ...       龜山區
#
#                address       cell tele id_num last_edit  bye note  任職公司  \
# ...

# %%
table1_select=table1.loc[:,['ID','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num']]
table1_select.head()
# Out:
#          ID           en_name  gender    birthday  age                  email  \
# 0  113435.0     WU, CHIH-CHEN     NaN  1997/03/03  NaN  joanwu11226@gmail.com
# 1  107203.0  HSIAO, CHUN-LING     NaN  1984/03/31  NaN  courage0331@gmail.com
# 2  105797.0               NaN     NaN  1994/10/08  NaN  derek831008@gmail.com
# 3   25768.0               NaN     NaN         NaN  NaN  sweetjeng@itri.org.tw
# 4   85662.0               NaN     1.0  1976/04/02  NaN  ryan.lu@moserbaer.net
#
#    zip_code region county district              address       cell  tele  \
# 0     220.0     TW    新北市      板橋區     新北市板橋區文聖街１８９號１４樓  987907091   NaN
# 1     108.0     TW    台北市      萬華區  台北市萬華區西園路２段９６巷３２號４樓  972929057   NaN
# 2       NaN    NaN    NaN      NaN                  NaN  975306253   NaN
# 3     300.0     TW    新竹市      東區光  新竹市東區光復路一段89巷159號6樓  981162089   NaN
# 4     333.0     TW    桃園市      龜山區    桃園市龜山區文二一街12號4樓之5  966996936   NaN
#
#   id_num
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# ...

# %%
table1_select_id=table1_select.dropna(subset=['ID'])
table1_select_id.head(20)
# Out:
#           ID           en_name  gender    birthday  age  \
# 0   113435.0     WU, CHIH-CHEN     NaN  1997/03/03  NaN
# 1   107203.0  HSIAO, CHUN-LING     NaN  1984/03/31  NaN
# 2   105797.0               NaN     NaN  1994/10/08  NaN
# 3    25768.0               NaN     NaN         NaN  NaN
# 4    85662.0               NaN     1.0  1976/04/02  NaN
# 5    84081.0               NaN     NaN         NaN  NaN
# 6   103913.0               NaN     0.0  1971/08/17  NaN
# 7     3321.0               NaN     1.0  1972/01/01  NaN
# 8    93935.0               NaN     1.0  1974/10/19  NaN
# 9   117364.0               NaN     NaN         NaN  NaN
# 11  103914.0               NaN     1.0  1972/03/10  NaN
# 12  103911.0               NaN     0.0  1973/11/15  NaN
# 13  114086.0        LIN, I-CHU     NaN  1974/05/22  NaN
# 19   94051.0               NaN     NaN         NaN  NaN
# 21  100605.0   TSENG, WEN-CHUN     NaN  1948/12/13  NaN
# 23  103546.0               NaN     0.0         NaN  NaN
# ...

# %%
table1_select_id.to_csv('001-250_clean.csv')

# %%
table1_select.head()
# Out:
#          ID           en_name  gender    birthday  age                  email  \
# 0  113435.0     WU, CHIH-CHEN     NaN  1997/03/03  NaN  joanwu11226@gmail.com
# 1  107203.0  HSIAO, CHUN-LING     NaN  1984/03/31  NaN  courage0331@gmail.com
# 2  105797.0               NaN     NaN  1994/10/08  NaN  derek831008@gmail.com
# 3   25768.0               NaN     NaN         NaN  NaN  sweetjeng@itri.org.tw
# 4   85662.0               NaN     1.0  1976/04/02  NaN  ryan.lu@moserbaer.net
#
#    zip_code region county district              address       cell  tele  \
# 0     220.0     TW    新北市      板橋區     新北市板橋區文聖街１８９號１４樓  987907091   NaN
# 1     108.0     TW    台北市      萬華區  台北市萬華區西園路２段９６巷３２號４樓  972929057   NaN
# 2       NaN    NaN    NaN      NaN                  NaN  975306253   NaN
# 3     300.0     TW    新竹市      東區光  新竹市東區光復路一段89巷159號6樓  981162089   NaN
# 4     333.0     TW    桃園市      龜山區    桃園市龜山區文二一街12號4樓之5  966996936   NaN
#
#   id_num
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# ...

# %%
table２_select=table1.loc[:,['ID','zh_name','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num']]
table2_id_null_mask=table2_select['ID'].isnull()
table2_idisnull=table2_select[table2_id_null_mask]
table2_idisnull
# Out:
#      ID zh_name en_name  gender    birthday  age                      email  \
# 10  NaN     黃昱銘     NaN     NaN         NaN  NaN       charis9106@gmail.com
# 14  NaN     梁淇涓     NaN     NaN         NaN  NaN                        NaN
# 15  NaN     陳怡榛     NaN     0.0  1977/11/29  NaN       zsuyin1129@gmail.com
# 16  NaN     黄美玲     NaN     NaN         NaN  NaN      marilyn@taifer.com.tw
# 17  NaN     李其曄     NaN     NaN         NaN  NaN         kiwi_lee@pj.com.tw
# 18  NaN     江梅愔     NaN     NaN         NaN  NaN        maycharis@gmail.com
# 20  NaN     吳宜學     NaN     1.0         NaN  NaN       wu58060505@gmail.com
# 22  NaN     嚴啓榮     NaN     NaN         NaN  NaN       chijungyen@gmail.com
# 26  NaN     林淑玲     NaN     0.0  1968/09/25  NaN       evajhsh@yahoo.com.tw
# 29  NaN     林穎芝     NaN     0.0  1981/06/10  NaN        maglinscu@gmail.com
# 43  NaN     蘇世銓     NaN     NaN         NaN  NaN                        NaN
# ...

# %%
table2_idisnull.to_csv('001-250_idnull.csv',encoding='utf-8-sig')

# %%
table1
# Out:
#      作業編號        ID                    畢業學系   年級 zh_name           en_name  \
# 0       1  113435.0                  資訊管理學系  108     巫沚臻     WU, CHIH-CHEN
# 1       2  107203.0                    法律學系  106     蕭君鈴  HSIAO, CHUN-LING
# 2       3  105797.0            經濟學系、108級企研所  106     黃奕豪               NaN
# 3       4   25768.0        85級經濟系研究所、83級經濟系   83     鄭淑穎               NaN
# 4       5   85662.0  96級英文系 /98級EMBA/06級經濟系   96     魯亮君               NaN
# ..    ...       ...                     ...  ...     ...               ...
# 245   246   96748.0                  日本語文學系   88     劉靜瑋               NaN
# 246   247   84563.0                  日本語文學系  103     吳怡逸               NaN
# 247   248       NaN                  日本語文學系  NaN     吳欣芳               NaN
# 248   249   67548.0                  日本語文學系  102     張孝薇               NaN
# 249   250  106875.0                  日本語文學系  106     陳奕廷               NaN
#
# ...
