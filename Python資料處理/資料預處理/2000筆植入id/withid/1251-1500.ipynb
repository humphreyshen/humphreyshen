# %%
import pandas as pd 
import numpy as np

table1=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆活動資料植入ID工作/原始csv檔區/1251-1500.csv')
table1
# Out:
#            id zh_name   年級  en_name  gender   birthday  age  \
# 0     22845.0    褚阮宗澤   81      NaN     NaN        NaN  NaN
# 1     22854.0     鍾智耀   81      NaN     NaN        NaN  NaN
# 2     24342.0     趙智勇   82      NaN     NaN        NaN  NaN
# 3     25858.0     謝文馨   83      NaN     NaN        NaN  NaN
# 4     27605.0     范光俊   84      NaN     NaN        NaN  NaN
# ..        ...     ...  ...      ...     ...        ...  ...
# 245   64439.0     潘尚霆  101      NaN     NaN  1990/8/10  NaN
# 246   97654.0     林逸婷  101      NaN     NaN        NaN  NaN
# 247  110966.0     林晏瑜  108      NaN     NaN        NaN  NaN
# 248       NaN     李宗勳   88      NaN     NaN        NaN  NaN
# 249   61986.0     賴奕臻  100      NaN     NaN        NaN  NaN
#
#                        email  zip_code region county district address  \
# 0        joerita@fpcc.com.tw       NaN    NaN    NaN      NaN     NaN
# 1    Yao0931232268@gmail.com       NaN    NaN    NaN      NaN     NaN
# ...

# %%
table1_select=table1.loc[:,['id','zh_name','年級','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num']]
table1_select.head()
# Out:
#         id zh_name  年級  en_name  gender birthday  age  \
# 0  22845.0    褚阮宗澤  81      NaN     NaN      NaN  NaN
# 1  22854.0     鍾智耀  81      NaN     NaN      NaN  NaN
# 2  24342.0     趙智勇  82      NaN     NaN      NaN  NaN
# 3  25858.0     謝文馨  83      NaN     NaN      NaN  NaN
# 4  27605.0     范光俊  84      NaN     NaN      NaN  NaN
#
#                      email  zip_code region county district address  \
# 0      joerita@fpcc.com.tw       NaN    NaN    NaN      NaN     NaN
# 1  Yao0931232268@gmail.com       NaN    NaN    NaN      NaN     NaN
# 2          JJY@YAHORNG.COM       NaN    NaN    NaN      NaN     NaN
# 3  cindy@premiercpa.com.tw       NaN    NaN    NaN      NaN     NaN
# 4      gavinfann@gmail.com       NaN    NaN    NaN      NaN     NaN
#
#            cell tele       id_num
# 0  0933-165-324  NaN   A121812985
# 1  0931-232-268  NaN   N120249363
# 2  0936-385-975  NaN   D120896293
# 3     915293955  NaN          NaN
# 4  0932-939-303  NaN   J120987212

# %%
table1_select.to_csv('1251-1500.csv',encoding='utf-8-sig')

# %%
table2=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆活動資料植入ID工作/原始csv檔區/1251-1500.csv')
table2
# Out:
#            id zh_name   年級  en_name  gender   birthday  age  \
# 0     22845.0    褚阮宗澤   81      NaN     NaN        NaN  NaN
# 1     22854.0     鍾智耀   81      NaN     NaN        NaN  NaN
# 2     24342.0     趙智勇   82      NaN     NaN        NaN  NaN
# 3     25858.0     謝文馨   83      NaN     NaN        NaN  NaN
# 4     27605.0     范光俊   84      NaN     NaN        NaN  NaN
# ..        ...     ...  ...      ...     ...        ...  ...
# 245   64439.0     潘尚霆  101      NaN     NaN  1990/8/10  NaN
# 246   97654.0     林逸婷  101      NaN     NaN        NaN  NaN
# 247  110966.0     林晏瑜  108      NaN     NaN        NaN  NaN
# 248       NaN     李宗勳   88      NaN     NaN        NaN  NaN
# 249   61986.0     賴奕臻  100      NaN     NaN        NaN  NaN
#
#                        email  zip_code region county district address  \
# 0        joerita@fpcc.com.tw       NaN    NaN    NaN      NaN     NaN
# 1    Yao0931232268@gmail.com       NaN    NaN    NaN      NaN     NaN
# ...

# %%
table3=table2.dropna(subset=['id'])
table3
# Out:
#            id zh_name   年級  en_name  gender   birthday  age  \
# 0     22845.0    褚阮宗澤   81      NaN     NaN        NaN  NaN
# 1     22854.0     鍾智耀   81      NaN     NaN        NaN  NaN
# 2     24342.0     趙智勇   82      NaN     NaN        NaN  NaN
# 3     25858.0     謝文馨   83      NaN     NaN        NaN  NaN
# 4     27605.0     范光俊   84      NaN     NaN        NaN  NaN
# ..        ...     ...  ...      ...     ...        ...  ...
# 240  105186.0     吳彥輝  106      NaN     NaN        NaN  NaN
# 245   64439.0     潘尚霆  101      NaN     NaN  1990/8/10  NaN
# 246   97654.0     林逸婷  101      NaN     NaN        NaN  NaN
# 247  110966.0     林晏瑜  108      NaN     NaN        NaN  NaN
# 249   61986.0     賴奕臻  100      NaN     NaN        NaN  NaN
#
#                        email  zip_code region county district address  \
# 0        joerita@fpcc.com.tw       NaN    NaN    NaN      NaN     NaN
# 1    Yao0931232268@gmail.com       NaN    NaN    NaN      NaN     NaN
# ...

# %%
table3.to_csv('1251-1500.csv',encoding='utf-8-sig')

# %%
idisnull=table2['id'].isnull()
idnull=table2[idisnull]
selected=idnull.loc[:,['id','zh_name','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num']]
selected
# Out:
#      id zh_name  en_name  gender    birthday  age  \
# 9   NaN     黃明添      NaN     NaN   1948/3/29  NaN
# 11  NaN     林綺珊      NaN     NaN   1956/4/24  NaN
# 15  NaN     徐藍朗      NaN     NaN   1994/5/23  NaN
# 30  NaN     蔡善如      NaN     NaN   1999/3/30  NaN
# 45  NaN     鄭國忠      NaN     NaN  1964/11/20  NaN
# 46  NaN      戴麗      NaN     NaN         NaN  NaN
# 56  NaN     郭思璞      NaN     NaN    1988/5/9  NaN
# 58  NaN     陳潔心      NaN     NaN         NaN  NaN
# 59  NaN     唐振嘉      NaN     NaN    1981/1/8  NaN
# 61  NaN     袁國珍      NaN     NaN         NaN  NaN
# 62  NaN     林瑞原      NaN     NaN         NaN  NaN
# 63  NaN     胡繼敏      NaN     NaN         NaN  NaN
# 64  NaN     張盛和      NaN     NaN    1949/9/1  NaN
# 69  NaN     林淑華      NaN     NaN         NaN  NaN
# 74  NaN    林思漩       NaN     NaN         NaN  NaN
# 79  NaN     蔡宜霖      NaN     NaN    1994/7/4  NaN
# 92  NaN     陳怡儒      NaN     NaN         NaN  NaN
# 97  NaN     陳鳳桃      NaN     NaN         NaN  NaN
# ...

# %%
selected.to_csv('1251-1500_idisnull.csv',encoding='utf-8-sig')
