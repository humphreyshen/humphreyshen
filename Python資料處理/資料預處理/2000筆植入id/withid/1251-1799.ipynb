# %%
import pandas as pd
import numpy as np

# %%
table_1251_1500=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆活動資料植入ID工作/personal正式上傳/1251-1500_withid.csv')
table_1251_1500.head()
# Out:
#       id zh_name  年級  en_name  gender birthday  age                    email  \
# 0  22845    褚阮宗澤  81      NaN     NaN      NaN  NaN      joerita@fpcc.com.tw
# 1  22854     鍾智耀  81      NaN     NaN      NaN  NaN  Yao0931232268@gmail.com
# 2  24342     趙智勇  82      NaN     NaN      NaN  NaN          JJY@YAHORNG.COM
# 3  25858     謝文馨  83      NaN     NaN      NaN  NaN  cindy@premiercpa.com.tw
# 4  27605     范光俊  84      NaN     NaN      NaN  NaN      gavinfann@gmail.com
#
#    zip_code region county district address          cell tele       id_num
# 0       NaN    NaN    NaN      NaN     NaN  0933-165-324  NaN   A121812985
# 1       NaN    NaN    NaN      NaN     NaN  0931-232-268  NaN   N120249363
# 2       NaN    NaN    NaN      NaN     NaN  0936-385-975  NaN   D120896293
# 3       NaN    NaN    NaN      NaN     NaN     915293955  NaN          NaN
# 4       NaN    NaN    NaN      NaN     NaN  0932-939-303  NaN   J120987212

# %%
table_1501_1750=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆活動資料植入ID工作/personal正式上傳/1501-1750_withid.csv')
table_1501_1750.head()
# Out:
#      id zh_name     年級 en_name gender    birthday  age  \
# 0   733     黃郁婷    NaN     NaN      0  1987/11/30  NaN
# 1  2053     吳怡萱    NaN     NaN    NaN         NaN  NaN
# 2  2391     王澤民  106.0     NaN    NaN         NaN  NaN
# 3  2451     葉衛廷    NaN     NaN    NaN  1986/11/14  NaN
# 4  2735     詹無愁    NaN     NaN    NaN         NaN  NaN
#
#                       email zip_code region county district address  \
# 0         1412388@gmail.com      NaN    NaN    NaN      NaN     NaN
# 1       wuyisuan@scu.edu.tw      NaN    NaN    NaN      NaN     NaN
# 2  wangtzermin@yahoo.com.tw      NaN    NaN    NaN      NaN     NaN
# 3       thor_gg@hotmail.com      NaN    NaN    NaN      NaN     NaN
# 4     fn6012g91@hotmail.com      NaN    NaN    NaN      NaN     NaN
#
#           cell tele      id_num  last_edit  bye  note
# 0  0973-731698  NaN  A227724495        NaN  NaN   NaN
# 1  0953-891206  NaN         NaN        NaN  NaN   NaN
# 2  0932-253824  NaN         NaN        NaN  NaN   NaN
# ...

# %%
table_1751_1799=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆活動資料植入ID工作/personal正式上傳/1751-1799_withid.csv')
table_1751_1799.head()
# Out:
#        id zh_name  年級  en_name  gender  birthday  age                  email  \
# 0  113687     蔡惠惠 NaN      NaN     NaN       NaN  NaN  joanna12099@gmail.com
# 1  102510      薛琪 NaN      NaN     NaN       NaN  NaN    z54782003@gmail.com
# 2  116419     許昱智 NaN      NaN     NaN       NaN  NaN                    NaN
# 3  117006     賴欣宜 NaN      NaN     NaN       NaN  NaN   hie123t@yahoo.com.tw
# 4  103536     郭冠頡 NaN      NaN     NaN       NaN  NaN                    NaN
#
#    zip_code  region  county  district  address         cell  tele      id_num
# 0       NaN     NaN     NaN       NaN      NaN  916408773.0   NaN         NaN
# 1       NaN     NaN     NaN       NaN      NaN  912064648.0   NaN  F228335291
# 2       NaN     NaN     NaN       NaN      NaN  989509925.0   NaN         NaN
# 3       NaN     NaN     NaN       NaN      NaN  909374984.0   NaN         NaN
# 4       NaN     NaN     NaN       NaN      NaN          NaN   NaN         NaN

# %%
concating=pd.concat([table_1251_1500,table_1501_1750,table_1751_1799])
concating
# Out:
#         id zh_name   年級 en_name gender birthday  age                    email  \
# 0    22845    褚阮宗澤   81     NaN    NaN      NaN  NaN      joerita@fpcc.com.tw
# 1    22854     鍾智耀   81     NaN    NaN      NaN  NaN  Yao0931232268@gmail.com
# 2    24342     趙智勇   82     NaN    NaN      NaN  NaN          JJY@YAHORNG.COM
# 3    25858     謝文馨   83     NaN    NaN      NaN  NaN  cindy@premiercpa.com.tw
# 4    27605     范光俊   84     NaN    NaN      NaN  NaN      gavinfann@gmail.com
# ..     ...     ...  ...     ...    ...      ...  ...                      ...
# 3   117006     賴欣宜  NaN     NaN    NaN      NaN  NaN     hie123t@yahoo.com.tw
# 4   103536     郭冠頡  NaN     NaN    NaN      NaN  NaN                      NaN
# 5   110351     郭家馨  NaN     NaN    NaN      NaN  NaN      c60123@yahoo.com.tw
# 6   116978     黃思堯  NaN     NaN    NaN      NaN  NaN        siyao39@gmail.com
# 7   110336     黃正文  NaN     NaN    NaN      NaN  NaN      egg80729@gmail.com
#
# ...

# %%
values = { "bye": 1}
fillna=concating.fillna(value=values)
fillna
# Out:
#         id zh_name   年級 en_name gender birthday  age                    email  \
# 0    22845    褚阮宗澤   81     NaN    NaN      NaN  NaN      joerita@fpcc.com.tw
# 1    22854     鍾智耀   81     NaN    NaN      NaN  NaN  Yao0931232268@gmail.com
# 2    24342     趙智勇   82     NaN    NaN      NaN  NaN          JJY@YAHORNG.COM
# 3    25858     謝文馨   83     NaN    NaN      NaN  NaN  cindy@premiercpa.com.tw
# 4    27605     范光俊   84     NaN    NaN      NaN  NaN      gavinfann@gmail.com
# ..     ...     ...  ...     ...    ...      ...  ...                      ...
# 3   117006     賴欣宜  NaN     NaN    NaN      NaN  NaN     hie123t@yahoo.com.tw
# 4   103536     郭冠頡  NaN     NaN    NaN      NaN  NaN                      NaN
# 5   110351     郭家馨  NaN     NaN    NaN      NaN  NaN      c60123@yahoo.com.tw
# 6   116978     黃思堯  NaN     NaN    NaN      NaN  NaN        siyao39@gmail.com
# 7   110336     黃正文  NaN     NaN    NaN      NaN  NaN      egg80729@gmail.com
#
# ...

# %%
final=fillna.loc[:,['id','zh_name','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num','last_edit','bye','note']]
final
# Out:
#         id zh_name en_name gender birthday  age                    email  \
# 0    22845    褚阮宗澤     NaN    NaN      NaN  NaN      joerita@fpcc.com.tw
# 1    22854     鍾智耀     NaN    NaN      NaN  NaN  Yao0931232268@gmail.com
# 2    24342     趙智勇     NaN    NaN      NaN  NaN          JJY@YAHORNG.COM
# 3    25858     謝文馨     NaN    NaN      NaN  NaN  cindy@premiercpa.com.tw
# 4    27605     范光俊     NaN    NaN      NaN  NaN      gavinfann@gmail.com
# ..     ...     ...     ...    ...      ...  ...                      ...
# 3   117006     賴欣宜     NaN    NaN      NaN  NaN     hie123t@yahoo.com.tw
# 4   103536     郭冠頡     NaN    NaN      NaN  NaN                      NaN
# 5   110351     郭家馨     NaN    NaN      NaN  NaN      c60123@yahoo.com.tw
# 6   116978     黃思堯     NaN    NaN      NaN  NaN        siyao39@gmail.com
# 7   110336     黃正文     NaN    NaN      NaN  NaN      egg80729@gmail.com
#
#    zip_code region county district address          cell tele       id_num  \
# ...

# %%
final.to_csv('1251-1799.csv',encoding='utf-8-sig')
