# %%
import numpy as np
import pandas as pd

table1=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/2000筆植入ID/原始csv檔區/251-500.csv')
table1
# Out:
#      作業編號        id zh_name         en_name  gender    birthday  age  \
# 0     251   73628.0     李淑芳             NaN     0.0         NaN  NaN
# 1     252   17024.0     王孟鈺             NaN     NaN    1966/5/1  NaN
# 2     253   96605.0     陳沛玲             NaN     0.0   1971/8/21  NaN
# 3     254   28827.0     陳琬菁             NaN     0.0  1974/10/28  NaN
# 4     255       NaN     黃靜儀             NaN     NaN         NaN  NaN
# ..    ...       ...     ...             ...     ...         ...  ...
# 245   496       NaN     温俊瑋             NaN     NaN         NaN  NaN
# 246   497   93449.0     簡嘉進             NaN     1.0  1976/12/26  NaN
# 247   498  110682.0     許志能  HSU, CHIH-NENG     1.0   1970/7/31  NaN
# 248   499       NaN     黃秀雲             NaN     0.0    1958/9/5  NaN
# 249   500   80962.0     張鑑鵬             NaN     1.0  1972/12/30  NaN
#
#                           email  zip_code region  ...          cell tele  \
# ...

# %%
table1_select=table1.loc[:,['id','zh_name','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num']]
table1_select
# Out:
#            id zh_name         en_name  gender    birthday  age  \
# 0     73628.0     李淑芳             NaN     0.0         NaN  NaN
# 1     17024.0     王孟鈺             NaN     NaN    1966/5/1  NaN
# 2     96605.0     陳沛玲             NaN     0.0   1971/8/21  NaN
# 3     28827.0     陳琬菁             NaN     0.0  1974/10/28  NaN
# 4         NaN     黃靜儀             NaN     NaN         NaN  NaN
# ..        ...     ...             ...     ...         ...  ...
# 245       NaN     温俊瑋             NaN     NaN         NaN  NaN
# 246   93449.0     簡嘉進             NaN     1.0  1976/12/26  NaN
# 247  110682.0     許志能  HSU, CHIH-NENG     1.0   1970/7/31  NaN
# 248       NaN     黃秀雲             NaN     0.0    1958/9/5  NaN
# 249   80962.0     張鑑鵬             NaN     1.0  1972/12/30  NaN
#
#                           email  zip_code region county district  \
# 0             ceo0520@gmail.com       NaN    NaN    NaN      NaN
# 1          monmom0501@gmail.com       NaN    NaN    NaN      NaN
# ...

# %%
table1_select_id=table1_select.dropna(subset=['id'])
table1_select_id.head(20)
# Out:
#           id zh_name en_name  gender    birthday  age  \
# 0    73628.0     李淑芳     NaN     0.0         NaN  NaN
# 1    17024.0     王孟鈺     NaN     NaN    1966/5/1  NaN
# 2    96605.0     陳沛玲     NaN     0.0   1971/8/21  NaN
# 3    28827.0     陳琬菁     NaN     0.0  1974/10/28  NaN
# 5    47497.0     李筱筠     NaN     NaN         NaN  NaN
# 6    86100.0     簡瑜寧     NaN     NaN         NaN  NaN
# 7     9934.0     邱若山     NaN     NaN         NaN  NaN
# 8   111798.0     李依軒     NaN     0.0         NaN  NaN
# 9   104900.0     徐紫婕     NaN     0.0   1990/10/6  NaN
# 10  111619.0     張添強     NaN     NaN   1993/10/7  NaN
# 11  101615.0     林禹彤     NaN     NaN   1994/3/26  NaN
# 12  101696.0     林敬心     NaN     0.0   1994/8/14  NaN
# 13  104949.0     葉靖怡     NaN     0.0   1994/12/2  NaN
# 14  110278.0     鄭湘蓓     NaN     NaN   1995/5/31  NaN
# 15  105058.0     黃均崴     NaN     NaN    1995/7/4  NaN
# 16  111634.0     陳惠賢     NaN     NaN   1996/8/28  NaN
# ...

# %%
table1_select_id.to_csv('251-500_clean.csv',encoding='utf-8-sig')
