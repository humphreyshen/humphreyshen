# %%
import pandas as pd
import numpy as np

personal_pre=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/001總表最新資料/2021-12-27-updated_csv/dDt_alumnidb_personal_pre.csv')
personal_pre
# Out:
#             id zh_name en_name  gender    birthday  age  \
# 0            1     殷葦婷     NaN     NaN         NaN  NaN
# 1            2     郭敬子     NaN     1.0         NaN  NaN
# 2            3     陳仕俍     NaN     NaN         NaN  NaN
# 3            4     郭珈郗     NaN     NaN         NaN  NaN
# 4            5     陸大文     NaN     1.0  1954-05-26  NaN
# ...        ...     ...     ...     ...         ...  ...
# 117819  117835     汪曼穎     NaN     0.0         NaN  NaN
# 117820  117836     侯佳彣     NaN     NaN         NaN  NaN
# 117821  117837     廖永森     NaN     NaN         NaN  NaN
# 117822  117838     楊東霖     NaN     NaN  1992-08-12  NaN
# 117823  117839     吳欣芳     NaN     NaN         NaN  NaN
#
#                           email zip_code region county district  \
# 0           13816630288@163.con       20     CN     20      NaN
# 1            jimkuo49@gmail.com      200     TW      C      仁愛區
# 2       gelintex@ms27.hinet.net      205     TW      C      暖暖區
# ...

# %%
personal_final=personal_pre.loc[:,['id','zh_name','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num','last_edit','bye','note']]
personal_cleaned=personal_final.replace({'\r':''},regex=True)
personal_cleaned
# Out:
#             id zh_name en_name  gender    birthday  age  \
# 0            1     殷葦婷     NaN     NaN         NaN  NaN
# 1            2     郭敬子     NaN     1.0         NaN  NaN
# 2            3     陳仕俍     NaN     NaN         NaN  NaN
# 3            4     郭珈郗     NaN     NaN         NaN  NaN
# 4            5     陸大文     NaN     1.0  1954-05-26  NaN
# ...        ...     ...     ...     ...         ...  ...
# 117819  117835     汪曼穎     NaN     0.0         NaN  NaN
# 117820  117836     侯佳彣     NaN     NaN         NaN  NaN
# 117821  117837     廖永森     NaN     NaN         NaN  NaN
# 117822  117838     楊東霖     NaN     NaN  1992-08-12  NaN
# 117823  117839     吳欣芳     NaN     NaN         NaN  NaN
#
#                           email zip_code region county district  \
# 0           13816630288@163.con       20     CN     20      NaN
# 1            jimkuo49@gmail.com      200     TW      C      仁愛區
# 2       gelintex@ms27.hinet.net      205     TW      C      暖暖區
# ...

# %%
personal_cleaned.to_csv('dDt_alumnidb_personal.csv',encoding='utf-8-sig')
