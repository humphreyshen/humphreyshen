# %%
import pandas as pd
import numpy as np

personal=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/001總表最新資料/2021-12-15_updated_csv/dDt_alumnidb_personal.csv')
personal
# Out:
# /Users/humphreyshen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             id zh_name           en_name  gender    birthday  age  \
# 0            1     殷葦婷               NaN     NaN         NaN  NaN
# 1            2     郭敬子               NaN     1.0         NaN  NaN
# 2            3     陳仕俍               NaN     NaN         NaN  NaN
# 3            4     郭珈郗               NaN     NaN         NaN  NaN
# 4            5     陸大文               NaN     1.0   1954/5/26  NaN
# ...        ...     ...               ...     ...         ...  ...
# 117583  117392     洪翔九               NaN     1.0   1983/5/22  NaN
# 117584  117393     吳幼倩               NaN     NaN    1967/6/8  NaN
# 117585  117394     張琇儀               NaN     0.0   1977/5/31  NaN
# ...

# %%
personalnull=personal['zh_name'].isnull()
personal_null=personal[personalnull]
personal_null
# Out:
#               id zh_name en_name  gender birthday  age email zip_code region  \
# 93            94     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 3321    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 4329    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 6148    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 6284    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# ...          ...     ...     ...     ...      ...  ...   ...      ...    ...
# 114366  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 114528  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 114875  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 115062  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 116257  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
#
# ...

# %%
personal_null[personal_null.id==';NULL;1"']
# Out:
#               id zh_name en_name  gender birthday  age email zip_code region  \
# 3321    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 4329    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 6148    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 6284    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 7137    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# ...          ...     ...     ...     ...      ...  ...   ...      ...    ...
# 114366  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 114528  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 114875  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 115062  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 116257  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
#
# ...

# %%
personal_null.to_csv('怪怪的.csv')

# %%
personal_1217=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/001總表最新資料/2021-12-17-updated_csv/dDt_alumnidb_personal.csv')
personal_1217
# Out:
# /Users/humphreyshen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             id zh_name           en_name  gender    birthday  age  \
# 0            1     殷葦婷               NaN     NaN         NaN  NaN
# 1            2     郭敬子               NaN     1.0         NaN  NaN
# 2            3     陳仕俍               NaN     NaN         NaN  NaN
# 3            4     郭珈郗               NaN     NaN         NaN  NaN
# 4            5     陸大文               NaN     1.0   1954/5/26  NaN
# ...        ...     ...               ...     ...         ...  ...
# 117584  117392     洪翔九               NaN     1.0   1983/5/22  NaN
# 117585  117393     吳幼倩               NaN     NaN    1967/6/8  NaN
# 117586  117394     張琇儀               NaN     0.0   1977/5/31  NaN
# ...

# %%
personal_1217[personal_1217.id==';NULL;1"']
# Out:
#               id zh_name en_name  gender birthday  age email zip_code region  \
# 5       ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 3322    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 4330    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 6149    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 6285    ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# ...          ...     ...     ...     ...      ...  ...   ...      ...    ...
# 114367  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 114529  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 114876  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 115063  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
# 116258  ;NULL;1"     NaN     NaN     NaN      NaN  NaN   NaN      NaN    NaN
#
# ...

# %%
concating=pd.concat([personal_1217,])
