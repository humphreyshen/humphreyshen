# %%
import pandas as pd
import numpy as np

# %%
Personal_pre=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/003數據預處理/Personal處理/2021-12-29/dDt_alumnidb_personal .csv')
Personal_pre
# Out:
#             id zh_name                      en_name  gender    birthday  age  \
# 0            1     殷葦婷                          NaN     NaN         NaN  NaN
# 1            2     郭敬子                          NaN     1.0         NaN  NaN
# 2            3     陳仕俍                          NaN     NaN         NaN  NaN
# 3            4     郭珈郗                          NaN     NaN         NaN  NaN
# 4            5     陸大文                          NaN     1.0  1954-05-26  NaN
# ...        ...     ...                          ...     ...         ...  ...
# 118387  118403     蔡吟欣    sgbunny01131119@gmail.com     NaN         NaN  NaN
# 118388  118404     曾珉妮         tsengminni@gmail.com     NaN         NaN  NaN
# 118389  118405      陳靖      chenching6728@gmail.com     NaN         NaN  NaN
# 118390  118406     莊雁筑  emilychuang0216@hotmail.com     NaN         NaN  NaN
# 118391  118407     周侑樺         suli354780@gmail.com     NaN         NaN  NaN
#
# ...

# %%
Personal_clean=Personal_pre.replace('\r','',regex=True)
Personal_clean
# Out:
#             id zh_name                      en_name  gender    birthday  age  \
# 0            1     殷葦婷                          NaN     NaN         NaN  NaN
# 1            2     郭敬子                          NaN     1.0         NaN  NaN
# 2            3     陳仕俍                          NaN     NaN         NaN  NaN
# 3            4     郭珈郗                          NaN     NaN         NaN  NaN
# 4            5     陸大文                          NaN     1.0  1954-05-26  NaN
# ...        ...     ...                          ...     ...         ...  ...
# 118387  118403     蔡吟欣    sgbunny01131119@gmail.com     NaN         NaN  NaN
# 118388  118404     曾珉妮         tsengminni@gmail.com     NaN         NaN  NaN
# 118389  118405      陳靖      chenching6728@gmail.com     NaN         NaN  NaN
# 118390  118406     莊雁筑  emilychuang0216@hotmail.com     NaN         NaN  NaN
# 118391  118407     周侑樺         suli354780@gmail.com     NaN         NaN  NaN
#
# ...

# %%
Personal_clean.to_csv('dDt_alumnidb_personal.csv',encoding='utf-8-sig')

# %%
Personal_vip=Personal_clean[Personal_clean.note=='important']
Personal_vip
# Out:
#             id zh_name                      en_name  gender    birthday  age  \
# 1            2     郭敬子                          NaN     1.0         NaN  NaN
# 2            3     陳仕俍                          NaN     NaN         NaN  NaN
# 4            5     陸大文                          NaN     1.0  1954-05-26  NaN
# 5            6     鄧淑珠                          NaN     NaN  1962-05-10  NaN
# 8            9     林筠鳳                          NaN     NaN         NaN  NaN
# ...        ...     ...                          ...     ...         ...  ...
# 118387  118403     蔡吟欣    sgbunny01131119@gmail.com     NaN         NaN  NaN
# 118388  118404     曾珉妮         tsengminni@gmail.com     NaN         NaN  NaN
# 118389  118405      陳靖      chenching6728@gmail.com     NaN         NaN  NaN
# 118390  118406     莊雁筑  emilychuang0216@hotmail.com     NaN         NaN  NaN
# 118391  118407     周侑樺         suli354780@gmail.com     NaN         NaN  NaN
#
# ...

# %%
Personal_vip.to_csv('2021-12-29-dDt_alumnidb_personal_VIPs.csv',encoding='utf-8-sig')
