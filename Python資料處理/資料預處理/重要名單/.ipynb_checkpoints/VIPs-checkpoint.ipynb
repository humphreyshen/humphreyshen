# %%
import pandas as pd
import numpy as np

# %%
Personal_original=pd.read_csv('/Users/humphreyshen/Desktop/dDt_alumnidb_personal_12_22.csv')
Personal_original
# Out:
#             id zh_name en_name  gender    birthday  age  \
# 0            1     殷葦婷     NaN     NaN         NaN  NaN
# 1            2     郭敬子     NaN     1.0         NaN  NaN
# 2            3     陳仕俍     NaN     NaN         NaN  NaN
# 3            4     郭珈郗     NaN     NaN         NaN  NaN
# 4            5     陸大文     NaN     1.0  1954-05-26  NaN
# ...        ...     ...     ...     ...         ...  ...
# 117819  117835     汪曼穎     NaN     0.0         NaN  NaN
# 117820  117836     侯佳彣     NaN     NaN         NaN  NaN
# 117821  117837     廖永森     NaN     NaN         NaN  NaN
# 117822  117838     楊東霖     NaN     NaN  1992-08-12  NaN
# 117823  117839     吳欣芳     NaN     NaN         NaN  NaN
#
#                           email zip_code region county district  \
# 0           13816630288@163.con       20     CN     20      NaN
# 1            jimkuo49@gmail.com      200     TW      C      仁愛區
# 2       gelintex@ms27.hinet.net      205     TW      C      暖暖區
# ...

# %%
Personal_select=Personal_original[Personal_original.note=='important']
Personal_select
# Out:
#             id zh_name en_name  gender    birthday  age  \
# 4            5     陸大文     NaN     1.0  1954-05-26  NaN
# 85          86     譚鎧承     NaN     1.0         NaN  NaN
# 732        733     黃郁婷     NaN     0.0  1987-11-30  NaN
# 2052      2053     吳怡萱     NaN     NaN         NaN  NaN
# 2390      2391     王澤民     NaN     NaN         NaN  NaN
# ...        ...     ...     ...     ...         ...  ...
# 117819  117835     汪曼穎     NaN     0.0         NaN  NaN
# 117820  117836     侯佳彣     NaN     NaN         NaN  NaN
# 117821  117837     廖永森     NaN     NaN         NaN  NaN
# 117822  117838     楊東霖     NaN     NaN  1992-08-12  NaN
# 117823  117839     吳欣芳     NaN     NaN         NaN  NaN
#
#                            email zip_code region county district  \
# 4         kathyhung168@gmail.com      105     TW      A      松山區
# 85         seven050302@gmail.com      NaN     MO    NaN      NaN
# 732            1412388@gmail.com      406     TW      B      北屯區
# ...

# %%
Personal_select_check=Personal_select.loc[:,['id','zh_name','en_name','gender','birthday','age','email','zip_code','region','county','district','address','cell','tele','id_num','last_edit','note']]
Personal_select_check
# Out:
#             id zh_name en_name  gender    birthday  age  \
# 4            5     陸大文     NaN     1.0  1954-05-26  NaN
# 85          86     譚鎧承     NaN     1.0         NaN  NaN
# 732        733     黃郁婷     NaN     0.0  1987-11-30  NaN
# 2052      2053     吳怡萱     NaN     NaN         NaN  NaN
# 2390      2391     王澤民     NaN     NaN         NaN  NaN
# ...        ...     ...     ...     ...         ...  ...
# 117819  117835     汪曼穎     NaN     0.0         NaN  NaN
# 117820  117836     侯佳彣     NaN     NaN         NaN  NaN
# 117821  117837     廖永森     NaN     NaN         NaN  NaN
# 117822  117838     楊東霖     NaN     NaN  1992-08-12  NaN
# 117823  117839     吳欣芳     NaN     NaN         NaN  NaN
#
#                            email zip_code region county district  \
# 4         kathyhung168@gmail.com      105     TW      A      松山區
# 85         seven050302@gmail.com      NaN     MO    NaN      NaN
# 732            1412388@gmail.com      406     TW      B      北屯區
# ...

# %%
Personal_clean=Personal_select_check.replace({'\r':''},regex=True)
Personal_clean
# Out:
#             id zh_name en_name  gender    birthday  age  \
# 4            5     陸大文     NaN     1.0  1954-05-26  NaN
# 85          86     譚鎧承     NaN     1.0         NaN  NaN
# 732        733     黃郁婷     NaN     0.0  1987-11-30  NaN
# 2052      2053     吳怡萱     NaN     NaN         NaN  NaN
# 2390      2391     王澤民     NaN     NaN         NaN  NaN
# ...        ...     ...     ...     ...         ...  ...
# 117819  117835     汪曼穎     NaN     0.0         NaN  NaN
# 117820  117836     侯佳彣     NaN     NaN         NaN  NaN
# 117821  117837     廖永森     NaN     NaN         NaN  NaN
# 117822  117838     楊東霖     NaN     NaN  1992-08-12  NaN
# 117823  117839     吳欣芳     NaN     NaN         NaN  NaN
#
#                            email zip_code region county district  \
# 4         kathyhung168@gmail.com      105     TW      A      松山區
# 85         seven050302@gmail.com      NaN     MO    NaN      NaN
# 732            1412388@gmail.com      406     TW      B      北屯區
# ...

# %%
Personal_clean.to_csv('dDt_alumnidb_personal_VIPs.csv',encoding='utf-8-sig')

# %%
Birthday_select=Personal_clean.dropna(subset=['birthday'])
Birthday_select
# Out:
#             id zh_name en_name  gender    birthday  age  \
# 4            5     陸大文     NaN     1.0  1954-05-26  NaN
# 732        733     黃郁婷     NaN     0.0  1987-11-30  NaN
# 2450      2451     葉衛廷     NaN     NaN  1986-11-14  NaN
# 3278      3279     許崇嘉     NaN     NaN  1990-12-23  NaN
# 3320      3321     余健銘     NaN     1.0  1972-01-01  NaN
# ...        ...     ...     ...     ...         ...  ...
# 117815  117831     徐寶華     NaN     0.0  1957-10-10  NaN
# 117816  117832     張源鈺     NaN     1.0  1983-01-18  NaN
# 117817  117833     張俊林     NaN     NaN  1986-02-13  NaN
# 117818  117834     吳羽柔     NaN     0.0  1988-03-05  NaN
# 117822  117838     楊東霖     NaN     NaN  1992-08-12  NaN
#
#                               email zip_code region county district  \
# 4            kathyhung168@gmail.com      105     TW      A      松山區
# 732               1412388@gmail.com      406     TW      B      北屯區
# 2450            thor_gg@hotmail.com      116     TW      A      文山區
# ...

# %%
Birthday_email=Birthday_select.dropna(subset=['email'])
Birthday_email
# Out:
#             id zh_name en_name  gender    birthday  age  \
# 4            5     陸大文     NaN     1.0  1954-05-26  NaN
# 732        733     黃郁婷     NaN     0.0  1987-11-30  NaN
# 2450      2451     葉衛廷     NaN     NaN  1986-11-14  NaN
# 3278      3279     許崇嘉     NaN     NaN  1990-12-23  NaN
# 3320      3321     余健銘     NaN     1.0  1972-01-01  NaN
# ...        ...     ...     ...     ...         ...  ...
# 117815  117831     徐寶華     NaN     0.0  1957-10-10  NaN
# 117816  117832     張源鈺     NaN     1.0  1983-01-18  NaN
# 117817  117833     張俊林     NaN     NaN  1986-02-13  NaN
# 117818  117834     吳羽柔     NaN     0.0  1988-03-05  NaN
# 117822  117838     楊東霖     NaN     NaN  1992-08-12  NaN
#
#                               email zip_code region county district  \
# 4            kathyhung168@gmail.com      105     TW      A      松山區
# 732               1412388@gmail.com      406     TW      B      北屯區
# 2450            thor_gg@hotmail.com      116     TW      A      文山區
# ...

# %%
Birthday_email.to_csv('VIPs_Birthdayemail.csv',encoding='utf-8-sig')
