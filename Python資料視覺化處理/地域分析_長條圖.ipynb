# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import figure
import seaborn as sns
# %matplotlib inline

raw_data_allpersonal = pd.read_csv ('/Users/humphreyshen/Desktop/Database Project/測試數據/alumni_event_participant/全體資料_114104.csv')

raw_data_allpersonal['zip_code'].plot(kind='hist',bins=369,width=5, color='Navy')
n_bins=369
plt.title("Population Histogram")
plt.title("Population Histogram")
plt.xlabel("Zip Code")
plt.ylabel("Population")
plt.grid(True)
plt.savefig("人口分布圖.jpg",dpi=500)
