# %%
import os 
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
raw_data = pd.read_csv ('/Users/humphreyshen/Desktop/Database Project/測試數據/alumnidb_personal/Table1_40001-50000_complete.csv')

raw_data

raw_data.head()
# Out:
#       id Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# 0  40001        林欣陵        NaN         NaN  1979/12/28         NaN        NaN
# 1  40002        張文潔        NaN         NaN         NaN         NaN        NaN
# 2  40003        曾健嘉        NaN         NaN         NaN         NaN        NaN
# 3  40004        洪欣怡        NaN         NaN         NaN         NaN        NaN
# 4  40005        徐意雯        NaN         NaN         NaN         NaN        NaN
#
#    zip_code Unnamed: 8 Unnamed: 9 Unnamed: 10         Unnamed: 11 Unnamed: 12  \
# 0     202.0         TW        基隆市         中正區      基隆市中正區環港街72號1樓         NaN
# 1     330.0         TW        桃園市         桃園區      桃園市桃園區孝一街13號2樓         NaN
# 2     302.0         TW        新竹縣         竹北市  新竹縣竹北市中華路761巷1弄16號         NaN
# 3     420.0         TW        台中市         豐原區    台中市豐原區中正路611巷15號         NaN
# 4     514.0         TW        彰化縣         溪湖鎮    彰化縣溪湖鎮汴頭里中興路104號         NaN
#
# ...

# %%
x = raw_data ['zip_code'].values
sns.distplot(x, color='blue')
# Out:
# /Users/humphreyshen/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
x = raw_data ['zip_code'].values
sns.distplot(x,bins=1000)
# Out:
# /Users/humphreyshen/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.relplot('zip_code','id',data=raw_data)
plt.savefig('123zip_code.jpg')
# Out:
# /Users/humphreyshen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import os 
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

raw_data_allpersonal = pd.read_csv ('/Users/humphreyshen/Desktop/Database Project/測試數據/alumni_event_participant/全體資料_114104.csv')
raw_data_allpersonal['zip_code'].plot(kind='hist');
# Out:
# /Users/humphreyshen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (5,7,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/bk/ms4pdg4d5tvglvf4crb9f83h0000gn/T/ipykernel_66435/1545481631.py in <module>
#       7
#       8 raw_data_allpernal = pd.read_csv ('/Users/humphreyshen/Desktop/Database Project/測試數據/alumni_event_participant/全體資料_114104.csv')
# ----> 9 raw_data_allpernal['zip_code'].plot(kind='hist');
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
# ...
