# %%
import pandas as pd
import numpy as np

full_data=pd.read_csv('/Users/humphreyshen/Desktop/2021 Database Project/001總表下載數據/df_orginal_withoutblank.csv')
full_data.head(10)
# Out:
# /Users/humphreyshen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (5,7,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    id zh_name en_name  gender   birthday  age                    email  \
# 0   1     殷葦婷     NaN     NaN        NaN  NaN      13816630288@163.con
# 1   2     郭敬子     NaN     1.0        NaN  NaN       jimkuo49@gmail.com
# 2   3     陳仕俍     NaN     NaN        NaN  NaN  gelintex@ms27.hinet.net
# 3   4     郭珈郗     NaN     NaN        NaN  NaN        grcekwk@gmail.com
# 4   5     陸大文     NaN     1.0  1954/5/26  NaN   kathyhung168@gmail.com
# 5   6     鄧淑珠     NaN     NaN  1962/5/10  NaN      terideng@scu.edu.tw
# 6   7     黃歆桀     NaN     NaN        NaN  NaN                      NaN
# 7   8     劉?偉     NaN     1.0  1955/8/17  NaN   tonyrush54@hotmail.com
# 8   9     林筠鳳     NaN     NaN        NaN  NaN    rosalin4547@gmail.com
# ...

# %%
ty_pre=full_data.loc[full_data.county=='桃園市',:]
ty_pre.head()
# Out:
#       id zh_name en_name  gender birthday  age               email zip_code  \
# 98    99     郭家安     NaN     NaN      NaN  NaN                 NaN      338
# 114  115     趙逸翔     NaN     NaN      NaN  NaN                 NaN      333
# 120  121     李昀蓁     NaN     NaN      NaN  NaN                 NaN      330
# 121  122     周薇華     NaN     0.0      NaN  NaN  nydia921@gmail.com      338
# 122  123     林以涵     NaN     NaN      NaN  NaN                 NaN      324
#
#     region county district                     address       cell tele id_num  \
# 98      TW    桃園市      蘆竹區            桃園市蘆竹區南福街63號2樓之2        NaN  NaN    NaN
# 114     TW    桃園市      龜山區           桃園市龜山區南上路520巷6弄4號        NaN  NaN    NaN
# 120     TW    桃園市      桃園區       桃園市桃園區桃園市桃園市復興路212號5F        NaN  NaN    NaN
# 121     TW    桃園市      蘆竹區       桃園市蘆竹區上竹村13鄰南竹路五段173號  983167080  NaN    NaN
# 122     TW    桃園市      平鎮區  桃園市平鎮區平興里33鄰延平路二段430巷51號7樓        NaN  NaN    NaN
#
#     last_edit  bye    note
# ...

# %%
ty_pre.shape
# Out:
# (7005, 18)

# %%
ty_clean1=ty_pre.replace('\r','',regex=True)
ty_clean1.head(15)
# Out:
#       id zh_name en_name  gender birthday  age               email zip_code  \
# 98    99     郭家安     NaN     NaN      NaN  NaN                 NaN      338
# 114  115     趙逸翔     NaN     NaN      NaN  NaN                 NaN      333
# 120  121     李昀蓁     NaN     NaN      NaN  NaN                 NaN      330
# 121  122     周薇華     NaN     0.0      NaN  NaN  nydia921@gmail.com      338
# 122  123     林以涵     NaN     NaN      NaN  NaN                 NaN      324
# 132  133     吳宥融     NaN     NaN      NaN  NaN                 NaN      320
# 177  178      軒漢     NaN     NaN      NaN  NaN                 NaN      330
# 178  179     吳任容     NaN     NaN      NaN  NaN                 NaN      330
# 179  180     潘冠諠     NaN     NaN      NaN  NaN                 NaN      326
# 180  181     許瀚予     NaN     NaN      NaN  NaN                 NaN      325
# 191  192     游筱郁     NaN     NaN      NaN  NaN                 NaN      320
# ...

# %%
ty_clean1.to_csv('Taoyuan_list.csv')
